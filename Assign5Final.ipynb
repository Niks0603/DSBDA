# %% [raw]
# Import all the required python libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score

# %% [raw]
# load the dataset name as (Social_Network_Ads_final)

# %%
df=pd.read_csv("Social_Network_Ads_final.csv")

# %%
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %% [raw]
# Show the dimensions

# %%
df.shape
# Out:
# (400, 5)

# %% [raw]
# show the names of all columns present in the dataset

# %%
df.columns
# Out:
# Index(['User ID', 'Gender', 'Age', 'EstimatedSalary', 'Purchased'], dtype='object')

# %% [raw]
# showing missing values in boolean type

# %%
df.isnull()
# Out:
#      User ID  Gender    Age  EstimatedSalary  Purchased
# 0      False   False  False            False      False
# 1      False   False  False            False      False
# 2      False   False  False            False      False
# 3      False   False  False            False      False
# 4      False   False  False            False      False
# ..       ...     ...    ...              ...        ...
# 395    False   False  False            False      False
# 396    False   False  False            False      False
# 397    False   False  False            False      False
# 398    False   False  False            False      False
# 399    False   False  False            False      False
#
# [400 rows x 5 columns]

# %% [raw]
# Checking missing values in a dataframe

# %%
df.isnull().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %% [raw]
# shows information of dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB

# %% [raw]
# show the otal number of elements in the DataFrame (i.e. Number of Rows x Number of Columns

# %%
df.size
# Out:
# 2000

# %% [raw]
# Showing datatypes of each column

# %%
df.dtypes
# Out:
# User ID             int64
# Gender             object
# Age                 int64
# EstimatedSalary     int64
# Purchased           int64
# dtype: object

# %% [raw]
# It gives statistical summary of a numerical column

# %%
df.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %% [raw]
# show the names of all columns present in the dataset

# %%
df.columns
# Out:
# Index(['User ID', 'Gender', 'Age', 'EstimatedSalary', 'Purchased'], dtype='object')

# %%
df.isnull().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
df
# Out:
#       User ID   Gender   Age  Estimated Salary  Purchased         City  \
# 0    75682867  Unknown  26.0           66955.0          1      Houston
# 1    66755036     male  55.0           76240.0          0  Los Angeles
# 2    66882282     Male  39.0           61607.0          1      Chicago
# 3    31081788        F  19.0           67870.0          1      Houston
# 4    23315092   female  41.0           79110.0          0      Chicago
# ..        ...      ...   ...               ...        ...          ...
# 995  60676914     Male  24.0           24221.0          0      Houston
# 996  36704425   female  52.0           16051.0          0     New York
# 997  71298111        F  45.0          125529.0          1     New York
# 998  55014515        F  31.0           91918.0          0      Chicago
# 999  64869006        F  27.0           93116.0          0          NaN
#
#     Device Used
# 0           Mac
# 1       Windows
# 2       Windows
# 3       Android
# 4       Android
# ..          ...
# 995         Mac
# 996     Windows
# 997         Mac
# 998     Windows
# 999     Windows
#
# [1000 rows x 7 columns]

# %%
# Step 1: Preprocess data
# Convert categorical columns (like Gender) to numeric if needed
if df['Gender'].dtype == 'object':
    df['Gender'] = LabelEncoder().fit_transform(df['Gender'])

# %%
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510       1   19            19000          0
# 1    15810944       1   35            20000          0
# 2    15668575       0   26            43000          0
# 3    15603246       0   27            57000          0
# 4    15804002       1   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863       0   46            41000          1
# 396  15706071       1   51            23000          1
# 397  15654296       0   50            20000          1
# 398  15755018       1   36            33000          0
# 399  15594041       0   49            36000          1
#
# [400 rows x 5 columns]

# %%
# Step 2: Feature and target split
X = df[['Age', 'EstimatedSalary', 'Gender']]  # Include relevant features
y = df['Purchased']

# %% [raw]
# train-test split configuration

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
# Step 4: Feature scaling
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Step 5: Train Logistic Regression model
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Step 6: Predictions
y_pred = model.predict(X_test)

# %% [raw]
# Confusion matrix conditions

# %%
cm = confusion_matrix(y_test, y_pred)
TP = cm[1, 1]
TN = cm[0, 0]
FP = cm[0, 1]
FN = cm[1, 0]

# %%
# Step 8: Metrics
accuracy = accuracy_score(y_test, y_pred)
error_rate = 1 - accuracy
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

# %%
# Step 9: Print results
print("Confusion Matrix:")
print(cm)
print(f"TP: {TP}, TN: {TN}, FP: {FP}, FN: {FN}")
print(f"Accuracy: {accuracy:.2f}")
print(f"Error Rate: {error_rate:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
# Out:
# Confusion Matrix:
# [[65  3]
#  [ 7 25]]
# TP: 25, TN: 65, FP: 3, FN: 7
# Accuracy: 0.90
# Error Rate: 0.10
# Precision: 0.89
# Recall: 0.78
